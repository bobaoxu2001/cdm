# %% [markdown]
# # Large Source Data Profiling
# Run `make profile` first, then review source profile outputs.

# %%
import pandas as pd
pd.read_csv('../data/outputs/source_profile_summary.csv').head()
