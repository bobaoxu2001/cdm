# %% [markdown]
# # Terminology Gap Analysis
# Review source fields that need vocabulary remediation.

# %%
import pandas as pd
terms = pd.read_csv('../data/outputs/terminology_alignment_report.csv')
terms[terms.status == 'terminology_gap'].head(20)
