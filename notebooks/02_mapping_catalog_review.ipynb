# %% [markdown]
# # Mapping Catalog Review
# Filter mapping statuses that need steward review.

# %%
import pandas as pd
catalog = pd.read_csv('../data/outputs/source_to_cdm_mapping_catalog.csv')
catalog[catalog.mapping_status.isin(['unmapped','review_required','partially_mapped'])].head(20)
